# %%
import pandas as pd

# %%
import requests , bs4

# %%
Url = "https://programmers.co.kr/"

# %%
requests.get(Url)
# Out:
# <Response [200]>

# %%
resp = requests.get(Url)

# %%
resp.text
# Out:
# '<!doctype html>\n<html lang="ko">\n<head>\n  <meta charset="utf-8">\n  <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no">\n  <meta http-equiv="x-ua-compatible" content="ie=edge">\n  <meta name="twitter:title" property="og:title" itemprop="title name" content="프로그래머스">\n<meta name="og:title" property="og:title" itemprop="title name" content="프로그래머스">\n<meta name="twitter:description" property="og:description" itemprop="description" content="SW개발자를 위한 평가, 교육, 채용까지 Total Solution을 제공하는 개발자 성장을 위한 베이스캠프">\n<meta name="og:description" property="og:description" itemprop="description" content="SW개발자를 위한 평가, 교육, 채용까지 Total Solution을 제공하는 개발자 성장을 위한 베이스캠프">\n<meta name="twitter:image" property="og:image" itemprop="image primaryImageOfPage" content="https://programmers.co.kr/assets/img-meta-programmers-411e94bf29153dc31004168e6cd500279b1a531a23689303755e51971dee4526.png">\n<meta name="og:image" property="og:image" itemprop="image primaryImageOfPage" content="https://programmers.co.kr/assets/img-meta-programmers-411e94bf29153dc31004168e6cd500279b1a531a23689303755e51971dee4526.png">\n<meta name="twitter:url" property="og:url" content="https://programmers.co.kr/">\n<meta name="og:url" property="og:url" content="https://programmers.co.kr/">\n<meta charset="utf-8">\n<title>프로그래머스</title>\n<link rel="shortcut icon" type="image/x-icon" href="https://programmers.co.kr/assets/icons/favicon-ec61d910396b5fc4d7418ea44281693172c34e31d437d074f9ab5470523990fb.png">\n<link rel="apple-touch-icon" type="image/png" href="https://programmers.co.kr/assets/icons/apple-icon-8a32ac937e12475676c7102e99d34b7f908b3d1ac048d6eed0712ad111bfdd01.png">\n<meta name="description" content="SW개발자를 위한 평가, 교육, 채용까지 Total Solution을 제공하는 개발자 성장을 위한 베이스캠프">\n<meta name="keywords" content="코딩 교육, 코딩, 프로그래밍, 실습, 생활코딩, 알고리즘">\n<meta property="fb:app_id" content="339079816467879">\n<meta property="og:type" content="website">\n<meta property="og:site_name" content="프로그래머스">\n<meta name="twitter:card" content="summary">\n  <meta name="csrf-param" content="authenticity_token" />\n<meta name="csrf-token" content="qsmcNAd8KWhIkcJBglyPqVhdVAI-OETapLhCFXD21hNRvhhHmO4zAddf2XaU3Bh67Fg4zRgfRsQs2uEsO-pmzA" />\n  <meta name="action-cable-url" content="wss://ws.programmers.co.kr:443/cable" />\n  <script type="text/javascript" charset="utf-8">\n  window.__env__ = {\n  STAGE: \'production\',\n  SITE: \'programmers\',\n  SENTRY_DSN: \'https://96f9fc1ff3f44acbb98a9c156338d14b@o1070092.ingest.sentry.io/6136918\',\n  HACKLE_BROWSER_KEY: \'OKQUz9iLXiTPyzwOAyq44sT4uwMqfCzz\',\n  HACKLE_EVENT_SERVER_INIT: true, // 핵클 초기화 코드 이전을 위한 임시 플래그 배포 후 삭제 예정\n  MINERVA_URL: \'minerva.programmers.co.kr\',\n  HERA_CLIENT_HOST: \'https://d1nuzc1w51n1es.cloudfront.net\',\n  PROGRAMMERS_HOST: \'programmers.co.kr\',\n  BUSINESS_HOST: \'business.programmers.co.kr\',\n  SCHOOL_HOST: \'school.programmers.co.kr\',\n  INSTRUCTOR_SCHOOL_HOST: \'instructor.school.programmers.co.kr\',\n  CAREER_HOST: \'career.programmers.co.kr\',\n  CAMPUS_HOST: \'campus.programmers.co.kr\',\n  PROGRAMMERS_WS_HOST: \'ws.programmers.co.kr\',\n  COMMUNITY_HOST: \'community.programmers.co.kr\',\n  QNA_HOST: \'qna.programmers.co.kr\',\n  IS_PROGRAMMERS_APP_REQUEST: false,\n};\n\n</script>\n  <script id="__hackle-init-info" data-user-id="" data-internal-account=""></script>\n<script src="/assets/hackle_event_initializer-44eba05105ba45283084261c453647f5081bbd5a6300a54cc53343f758dea00e.js"></script>\n\n\n    <!-- Google Tag Manager -->\n<script>(function (w, d, s, l, i) {\n  w[l] = w[l] || [];\n  w[l].push({\n    \'gtm.start\':\n      new Date().getTime(), event: \'gtm.js\'\n  });\n  var f = d.getElementsByTagName(s)[0],\n    j = d.createElement(s), dl = l != \'dataLayer\' ? \'&l=\' + l : \'\';\n  j.async = true;\n  j.src =\n    \'https://www.googletagmanager.com/gtm.js?id=\' + i + dl;\n  f.parentNode.insertBefore(j, f);\n})(window, document, \'script\', \'dataLayer\', \'GTM-NT8HLJD\');</scri ...

# %%
htmlObj = resp.text

# %%
bsObj = bs4.BeautifulSoup(htmlObj,"html.parser")

# %%
bsObj
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="프로그래머스" itemprop="title name" name="twitter:title" property="og:title"/>
# <meta content="프로그래머스" itemprop="title name" name="og:title" property="og:title"/>
# <meta content="SW개발자를 위한 평가, 교육, 채용까지 Total Solution을 제공하는 개발자 성장을 위한 베이스캠프" itemprop="description" name="twitter:description" property="og:description"/>
# <meta content="SW개발자를 위한 평가, 교육, 채용까지 Total Solution을 제공하는 개발자 성장을 위한 베이스캠프" itemprop="description" name="og:description" property="og:description"/>
# <meta content="https://programmers.co.kr/assets/img-meta-programmers-411e94bf29153dc31004168e6cd500279b1a531a23689303755e51971dee4526.png" itemprop="image primaryImageOfPage" name="twitter:image" property="og:image"/>
# <meta content="https://programmers.co.kr/assets/img-meta-programmers-411e94bf29153dc31004168e6cd500279b1a531a23689303755e51971dee4526.png" itemprop="image primaryImageOfPage" name="og:image" property="og:image"/>
# <meta content="https://programmers.co.kr/" name="twitter:url" property="og:url"/>
# <meta content="https://programmers.co.kr/" name="og:url" property="og:url"/>
# <meta charset="utf-8"/>
# <title>프로그래머스</title>
# <link href="https://programmers.co.kr/assets/icons/favicon-ec61d910396b5fc4d7418ea44281693172c34e31d437d074f9ab5470523990fb.png" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://programmers.co.kr/assets/icons/apple-icon-8a32ac937e12475676c7102e99d34b7f908b3d1ac048d6eed0712ad111bfdd01.png" rel="apple-touch-icon" type="image/png"/>
# <meta content="SW개발자를 위한 평가, 교육, 채용까지 Total Solution을 제공하는 개발자 성장을 위한 베이스캠프" name="description"/>
# <meta content="코딩 교육, 코딩, 프로그래밍, 실습, 생활코딩, 알고리즘" name="keywords"/>
# <meta content="339079816467879" property="fb:app_id"/>
# <meta content="website" property="og:type"/>
# <meta content="프로그래머스" property="og:site_name"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="authenticity_token" name="csrf-param">
# <meta content="qsmcNAd8KWhIkcJBglyPqVhdVAI-OETapLhCFXD21hNRvhhHmO4zAddf2XaU3Bh67Fg4zRgfRsQs2uEsO-pmzA" name="csrf-token">
# <meta content="wss://ws.programmers.co.kr:443/cable" name="action-cable-url">
# <script charset="utf-8" type="text/javascript">
#   window.__env__ = {
#   STAGE: 'production',
#   SITE: 'programmers',
#   SENTRY_DSN: 'https://96f9fc1ff3f44acbb98a9c156338d14b@o1070092.ingest.sentry.io/6136918',
#   HACKLE_BROWSER_KEY: 'OKQUz9iLXiTPyzwOAyq44sT4uwMqfCzz',
#   HACKLE_EVENT_SERVER_INIT: true, // 핵클 초기화 코드 이전을 위한 임시 플래그 배포 후 삭제 예정
#   MINERVA_URL: 'minerva.programmers.co.kr',
#   HERA_CLIENT_HOST: 'https://d1nuzc1w51n1es.cloudfront.net',
#   PROGRAMMERS_HOST: 'programmers.co.kr',
#   BUSINESS_HOST: 'business.programmers.co.kr',
#   SCHOOL_HOST: 'school.programmers.co.kr',
#   INSTRUCTOR_SCHOOL_HOST: 'instructor.school.programmers.co.kr',
#   CAREER_HOST: 'career.programmers.co.kr',
#   CAMPUS_HOST: 'campus.programmers.co.kr',
#   PROGRAMMERS_WS_HOST: 'ws.programmers.co.kr',
#   COMMUNITY_HOST: 'community.programmers.co.kr',
#   QNA_HOST: 'qna.programmers.co.kr',
#   IS_PROGRAMMERS_APP_REQUEST: false,
# };
#
# </script>
# <script data-internal-account="" data-user-id="" id="__hackle-init-info"></script>
# <script src="/assets/hackle_event_initializer-44eba05105ba45283084261c453647f5081bbd5a6300a54cc53343f758dea00e.js"></script>
# <!-- Google Tag Manager -->
# <script>(function (w, d, s, l, i) {
#   w[l] = w[l] || [];
#   w[l].push({
#     'gtm.start':
#       new Date().getTime(), event: 'gtm.js'
#   });
#   var f = d.getElementsByTagName(s)[0],
#     j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
#   j.async = true;
#   j.src =
#     'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
#   f.parentNode.insertBefore(j, f);
# })(window, document, 'script', 'dataLayer', 'GTM-NT8HLJD');</script>
# <!-- End Google Tag Manager -->
# <link href="https://d1nuzc1w51n1es.cloudfront.net/abefea36bd0ce2863894.css" rel="stylesheet">
# </link></meta></meta></meta></head>
# <body data-flash-message="" data-signed-in="false">
# <link href="https://d1nuzc1w51n1es.cloudfront.net/9fd52beab9deebf912bf.css" rel="stylesheet"/><style data-styled="true" data-styled-version="5.3.6">.bnJBSh > path{fill:#84919E;-webkit-transition:fill 0.2s ease-out;transition:fill 0.2s ease-out;}/*!sc*/
# data-styled.g4[id="OneDepthNavItemstyle__StyledIcLaunch-sc-4cmp4x-0"]{content:"bnJBSh,"}/*!sc*/
# .uFIxo{padding:20px 20px 20px;border-bottom:0px;height:66px;color:#0F1317;font-size:16px;font-weight:500;line-height:150%;-webkit-transition-property:border-bottom,color,font-weight;transition-property:border-bottom,color,font-weight;-webkit-transition-duration:0.2s;transition-duration:0.2s;-webkit-transition-timing-function:ease-out;transition-timing-function:ease-out;color:#0F1317;}/*!sc*/
# .uFIxo:hover .OneDepthNavItemstyle__StyledIcLaunch-sc-4cmp4x-0 > path{fill:#0F1317;}/*!sc*/
# data-styled.g5[id="OneDepthNavItemstyle__Content-sc-4cmp4x-1"]{content:"uFIxo,"}/*!sc*/
# .hEBFsL{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# data-styled.g6[id="OneDepthNavItemstyle__Wrapper-sc-4cmp4x-2"]{content:"hEBFsL,"}/*!sc*/
# .Tsxcg{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# @media (max-width:991px){.Tsxcg{display:none;}}/*!sc*/
# data-styled.g7[id="DesktopGnbMainMenuListstyle__Container-sc-8ebl73-0"]{content:"Tsxcg,"}/*!sc*/
# .kiBsKV > path{fill:#84919E;-webkit-transition:fill 0.2s ease-out;transition:fill 0.2s ease-out;}/*!sc*/
# data-styled.g8[id="NavLinkstyle__StyledIcLaunch-sc-a5lqib-0"]{content:"kiBsKV,"}/*!sc*/
# .jsnXoS{line-height:150%;color:#0F1317;-webkit-transition:color 0.2s ease-out;transition:color 0.2s ease-out;}/*!sc*/
# data-styled.g9[id="NavLinkstyle__LinkText-sc-a5lqib-1"]{content:"jsnXoS,"}/*!sc*/
# .bnEtuJ.bnEtuJ{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;gap:2px;padding:8px 16px 7px;min-width:60%;}/*!sc*/
# @media (max-width:991px){.bnEtuJ.bnEtuJ{min-width:100%;}}/*!sc*/
# .bnEtuJ.bnEtuJ > div{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;gap:8px;}/*!sc*/
# .bnEtuJ.bnEtuJ:hover .NavLinkstyle__LinkText-sc-a5lqib-1{color:#0078FF;}/*!sc*/
# .bnEtuJ.bnEtuJ:hover .NavLinkstyle__StyledIcLaunch-sc-a5lqib-0 > path{fill:#0078FF;}/*!sc*/
# data-styled.g10[id="NavLinkstyle__Link-sc-a5lqib-2"]{content:"bnEtuJ,"}/*!sc*/
# .jYxOYc{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;color:#0078FF;font-size:12px;font-weight:700;line-height:150%;margin-left:8px;}/*!sc*/
# data-styled.g11[id="NavLinkstyle__Badge-sc-a5lqib-3"]{content:"jYxOYc,"}/*!sc*/
# .kpddAR{position:absolute;top:100%;width:100%;background-color:#ffffff;overflow:hidden;height:0;-webkit-transition:height 0.3s ease-out;transition:height 0.3s ease-out;}/*!sc*/
# .kpddAR[aria-expanded='true']{background-color:#ffffff;}/*!sc*/
# @media (max-width:991px){.kpddAR{display:none;}}/*!sc*/
# data-styled.g12[id="DesktopGnbSubMenuItemstyle__Container-sc-usvvmw-0"]{content:"kpddAR,"}/*!sc*/
# .gpjoMd{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;padding:16px 0 24px;}/*!sc*/
# data-styled.g13[id="DesktopGnbSubMenuItemstyle__TwoDepthNavContainer-sc-usvvmw-1"]{content:"gpjoMd,"}/*!sc*/
# .bSIgPM > li{margin-bottom:24px;}/*!sc*/
# .bSIgPM > li:last-of-type{margin-bottom:0px;}/*!sc*/
# data-styled.g14[id="DesktopGnbSubMenuItemstyle__TwoDepthNavList-sc-usvvmw-2"]{content:"bSIgPM,"}/*!sc*/
# .hUDsDw{display:grid;grid-template-columns:1fr 1fr 1fr;width:100%;max-width:1160px;}/*!sc*/
# data-styled.g15[id="DesktopGnbSubMenuItemstyle__Grid-sc-usvvmw-3"]{content:"hUDsDw,"}/*!sc*/
# .fbOEDL{font-size:16px;font-weight:700;}/*!sc*/
# data-styled.g16[id="DesktopGnbSubMenuItemstyle__TwoDepthNavLink-sc-usvvmw-4"]{content:"fbOEDL,"}/*!sc*/
# .GDJFV{font-size:14px;font-weight:400;}/*!sc*/
# data-styled.g17[id="DesktopGnbSubMenuItemstyle__ThreeDepthNavLink-sc-usvvmw-5"]{content:"GDJFV,"}/*!sc*/
# .eXasnG.eXasnG{margin-right:60px;line-height:0;}/*!sc*/
# @media (max-width:991px){.eXasnG.eXasnG{margin-left:20px;margin-right:0;}}/*!sc*/
# data-styled.g19[id="LogoLinkstyle__LogoLink-sc-pnxc3t-0"]{content:"eXasnG,"}/*!sc*/
# .ioKwrR > path{fill:#84919E;-webkit-transition:fill 0.2s ease-out;transition:fill 0.2s ease-out;}/*!sc*/
# data-styled.g20[id="MobileGnbMainMenuListstyle__StyledIcLaunch-sc-1i37ssv-0"]{content:"ioKwrR,"}/*!sc*/
# .dLgmTS{padding:16px 20px;color:#667380;font-size:16px;font-weight:500;line-height:150%;cursor:pointer;background-color:#F5F6F7;-webkit-transition-property:color,background-color,font-weight;transition-property:color,background-color,font-weight;-webkit-transition-duration:0.2s;transition-duration:0.2s;-webkit-transition-timing-function:ease-out;transition-timing-function:ease-out;color:#0F1317;background-color:#ffffff;font-weight:700;}/*!sc*/
# .dLgmTS:active,.dLgmTS:hover{color:#0F1317;background-color:#ffffff;font-weight:700;}/*!sc*/
# .hLCCcb{padding:16px 20px;color:#667380;font-size:16px;font-weight:500;line-height:150%;cursor:pointer;background-color:#F5F6F7;-webkit-transition-property:color,background-color,font-weight;transition-property:color,background-color,font-weight;-webkit-transition-duration:0.2s;transition-duration:0.2s;-webkit-transition-timing-function:ease-out;transition-timing-function:ease-out;}/*!sc*/
# .hLCCcb:active,.hLCCcb:hover{color:#0F1317;background-color:#ffffff;font-weight:700;}/*!sc*/
# data-styled.g21[id="MobileGnbMainMenuListstyle__NavMenuItem-sc-1i37ssv-1"]{content:"dLgmTS,hLCCcb,"}/*!sc*/
# .gkNgzN{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:16px 20px;color:#667380;font-size:16px;font-weight:500;line-height:150%;cursor:pointer;background-color:#F5F6F7;}/*!sc*/
# .gkNgzN:active,.gkNgzN:hover{color:#0F1317;background-color:#ffffff;font-weight:700;}/*!sc*/
# .gkNgzN:hover .MobileGnbMainMenuListstyle__StyledIcLaunch-sc-1i37ssv-0 > path{fill:#0F1317;}/*!sc*/
# data-styled.g22[id="MobileGnbMainMenuListstyle__NavMenuItemExternal-sc-1i37ssv-2"]{content:"gkNgzN,"}/*!sc*/
# .cBeKSj{display:block;position:absolute;top:0;right:0;bottom:0;left:0;-webkit-flex:1;-ms-flex:1;flex:1;padding:8px 16px 16px;background-color:#ffffff;overflow-y:auto;}/*!sc*/
# .cBeKSj::-webkit-scrollbar{width:8px;}/*!sc*/
# .cBeKSj::-webkit-scrollbar-track{background-color:#EDEFF2;}/*!sc*/
# .cBeKSj::-webkit-scrollbar-thumb{border-radius:40px;background-color:#BEC7D1;}/*!sc*/
# .jqCaUI{display:none;position:absolute;top:0;right:0;bottom:0;left:0;-webkit-flex:1;-ms-flex:1;flex:1;padding:8px 16px 16px;background-color:#ffffff;overflow-y:auto;}/*!sc*/
# .jqCaUI::-webkit-scrollbar{width:8px;}/*!sc*/
# .jqCaUI::-webkit-scrollbar-track{background-color:#EDEFF2;}/*!sc*/
# .jqCaUI::-webkit-scrollbar-thumb{border-radius:40px;background-color:#BEC7D1;}/*!sc*/
# data-styled.g23[id="MobileGnbSubMenuListstyle__SubMenuItem-sc-ihy9ar-0"]{content:"cBeKSj,jqCaUI,"}/*!sc*/
# .cnxmsx{margin-bottom:16px;}/*!sc*/
# .cnxmsx:last-of-type{margin-bottom:0;}/*!sc*/
# data-styled.g24[id="MobileGnbSubMenuListstyle__TwoAndThreeDepthContainer-sc-ihy9ar-1"]{content:"cnxmsx,"}/*!sc*/
# .hnsIGR{padding:8px 16px;font-size:16px;font-weight:700;}/*!sc*/
# data-styled.g25[id="MobileGnbSubMenuListstyle__TwoDepthNavLink-sc-ihy9ar-2"]{content:"hnsIGR,"}/*!sc*/
# .jIrZgU{padding:8px 16px 7px;font-size:14px;font-weight:400;}/*!sc*/
# data-styled.g26[id="MobileGnbSubMenuListstyle__ThreeDepthNavLink-sc-ihy9ar-3"]{content:"jIrZgU,"}/*!sc*/
# .bBXcZq{background-color:#ffffff;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;width:100%;height:100%;}/*!sc*/
# data-styled.g27[id="MobileGnbstyle__Container-sc-yi1ct8-0"]{content:"bBXcZq,"}/*!sc*/
# .kLIIVp{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;width:100%;height:64px;border-bottom:1px solid #DCE1E6;padding-right:8px;}/*!sc*/
# data-styled.g28[id="MobileGnbstyle__TopBar-sc-yi1ct8-1"]{content:"kLIIVp,"}/*!sc*/
# .ioixrH{padding:8px;line-height:0;}/*!sc*/
# data-styled.g29[id="MobileGnbstyle__CloseButton-sc-yi1ct8-2"]{content:"ioixrH,"}/*!sc*/
# .dctwnN{-webkit-flex:1;-ms-flex:1;flex:1;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# data-styled.g30[id="MobileGnbstyle__Content-sc-yi1ct8-3"]{content:"dctwnN,"}/*!sc*/
# .bPgiQu{width:35%;min-width:120px;max-width:240px;background-color:#EDEFF2;}/*!sc*/
# data-styled.g31[id="MobileGnbstyle__MainMenuGroup-sc-yi1ct8-4"]{content:"bPgiQu,"}/*!sc*/
# .kAvPeW{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;height:100%;}/*!sc*/
# data-styled.g32[id="MobileGnbstyle__MainMenuGroupInner-sc-yi1ct8-5"]{content:"kAvPeW,"}/*!sc*/
# .gjUoGp{padding:16px 20px;color:#667380;font-size:16px;font-weight:500;line-height:150%;cursor:pointer;}/*!sc*/
# data-styled.g33[id="MobileGnbstyle__MenuItem-sc-yi1ct8-6"]{content:"gjUoGp,"}/*!sc*/
# .ioLese{display:block;background-color:#EDEFF2;-webkit-transition-property:color,background-color;transition-property:color,background-color;-webkit-transition-duration:0.2s;transition-duration:0.2s;-webkit-transition-timing-function:ease-out;transition-timing-function:ease-out;}/*!sc*/
# .ioLese:hover,.ioLese:active{background-color:#dce1e5;}/*!sc*/
# data-styled.g34[id="MobileGnbstyle__UtilMenuItem-sc-yi1ct8-7"]{content:"ioLese,"}/*!sc*/
# .fdAYMF{margin-inline:20px;margin-bottom:20px;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;max-width:200px;width:calc(100% - 40px);background-color:#ffffff;border:1px solid #D7E2EB;border-radius:4px;padding:5px 13px;color:#2C323B;font-size:14px;font-weight:500;line-height:150%;cursor:pointer;}/*!sc*/
# .fdAYMF:hover{border-color:#E9ECF3;background-color:#E9ECF3;}/*!sc*/
# .fdAYMF:focus{border-color:#D7E2EB;background-color:#ffffff;box-shadow:0px 0px 0px 3.2px rgba(233,236,243,0.5);}/*!sc*/
# data-styled.g35[id="MobileGnbstyle__BorderedLink-sc-yi1ct8-8"]{content:"fdAYMF,"}/*!sc*/
# .fZmZMC{position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-flex:1;-ms-flex:1;flex:1;}/*!sc*/
# data-styled.g36[id="MobileGnbstyle__SubMenuGroup-sc-yi1ct8-9"]{content:"fZmZMC,"}/*!sc*/
# .uteMI{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:40px;height:40px;line-height:0;}/*!sc*/
# @media (min-width:992px){.uteMI{display:none;}}/*!sc*/
# data-styled.g37[id="MobileMenuButtonstyle__MobileMenuButton-sc-9nyyno-0"]{content:"uteMI,"}/*!sc*/
# .ipUjXl{position:relative;background-color:#ffffff;}/*!sc*/
# .ipUjXl ul,.ipUjXl li{list-style:none;}/*!sc*/
# data-styled.g79[id="GlobalHeaderstyle__Header-sc-16dbplc-0"]{content:"ipUjXl,"}/*!sc*/
# .jvlxFY{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;border-bottom:1px solid #DCE1E6;}/*!sc*/
# .jvlxFY > div{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;width:100%;max-width:1200px;height:64px;padding:0 20px;}/*!sc*/
# @media (max-width:991px){.jvlxFY > div{padding:0;}}/*!sc*/
# data-styled.g80[id="GlobalHeaderstyle__MainSection-sc-16dbplc-1"]{content:"jvlxFY,"}/*!sc*/
# .eKGSpe{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;width:100%;-webkit-flex:1 0 0;-ms-flex:1 0 0;flex:1 0 0;}/*!sc*/
# @media (max-width:991px){.eKGSpe{width:unset;-webkit-flex:unset;-ms-flex:unset;flex:unset;margin-right:8px;gap:4px;}}/*!sc*/
# data-styled.g81[id="GlobalHeaderstyle__MenuGroup-sc-16dbplc-2"]{content:"eKGSpe,"}/*!sc*/
# .hTFzBt{position:fixed;top:0;right:0;bottom:0;width:100%;z-index:8100;-webkit-transform:translateX(100%);-ms-transform:translateX(100%);transform:translateX(100%);-webkit-transition:-webkit-transform 0.3s ease-out;-webkit-transition:transform 0.3s ease-out;transition:transform 0.3s ease-out;}/*!sc*/
# @media (min-width:992px){.hTFzBt{display:none;}}/*!sc*/
# data-styled.g82[id="GlobalHeaderstyle__MobileGnbContainer-sc-16dbplc-3"]{content:"hTFzBt,"}/*!sc*/
# </style><div id="main-app-header"><header class="GlobalHeaderstyle__Header-sc-16dbplc-0 ipUjXl" data-testid="main-app-header"><section class="GlobalHeaderstyle__MainSection-sc-16dbplc-1 jvlxFY"><div><a aria-label="프로그래머스 로고 링크" class="LogoLinkstyle__LogoLink-sc-pnxc3t-0 eXasnG" data-hackle-value='{"key":"gnb_clicked","properties":{"entry_route":"","depth1":"logo"}}' href="https://programmers.co.kr"><svg fill="none" height="25" viewbox="0 0 178 25" width="178" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M175.306 8.423a2.575 2.575 0 0 0-.932-.765 2.522 2.522 0 0 0-1.17-.25c-.313 0-.621.076-.898.223a.766.766 0 0 0-.336.314.796.796 0 0 0-.101.454.674.674 0 0 0 .449.653c.367.162.749.287 1.14.374l1.476.344a5.534 5.534 0 0 1 1.477.604c.458.26.849.63 1.14 1.076a3.29 3.29 0 0 1 .443 1.813 3.434 3.434 0 0 1-.496 1.921c-.327.497-.762.91-1.27 1.208-.55.317-1.15.534-1.772.64a9.88 9.88 0 0 1-1.914.188 9.2 9.2 0 0 1-2.492-.356 4.652 4.652 0 0 1-2.132-1.275l2.203-2.508a3.56 3.56 0 0 0 1.128.98c.445.232.94.349 1.441.338.386.006.77-.057 1.134-.188a.657.657 0 0 0 .373-.248.689.689 0 0 0 .135-.435.766.766 0 0 0-.117-.422.742.742 0 0 0-.326-.284 4.939 4.939 0 0 0-1.14-.393l-1.477-.35a5.884 5.884 0 0 1-1.476-.557 2.922 2.922 0 0 1-1.22-1.188 3.017 3.017 0 0 1-.369-1.682 3.738 3.738 0 0 1 .425-1.812 3.8 3.8 0 0 1 1.116-1.263 4.678 4.678 0 0 1 1.583-.731 7.137 7.137 0 0 1 1.82-.236c.799 0 1.595.119 2.362.35a4.306 4.306 0 0 1 2.014 1.21zm-15.982-3.547h3.632V6.81h.053a4.546 4.546 0 0 1 1.377-1.674 3.481 3.481 0 0 1 2.014-.556h.626c.199.017.397.051.59.103v3.39a5.21 5.21 0 0 0-.768-.182 4.612 4.612 0 0 0-.785-.066 3.787 3.787 0 0 0-1.648.302 2.179 2.179 0 0 0-.933.828c-.225.39-.368.824-.419 1.274-.069.543-.103 1.09-.101 1.638v5.051h-3.632zm-5.316 4.659a2.185 2.185 0 0 0-.131-.867 2.131 2.131 0 0 0-.46-.74 2.142 2.142 0 0 0-1.624-.671 2.639 2.639 0 0 0-1.854.707 2.339 2.339 0 0 0-.508.719 2.34 2.34 0 0 0-.201.852zm3.077 5.305a5.888 5.888 0 0 1-2.203 1.758 6.488 6.488 0 0 1-2.758.604 7.15 7.15 0 0 1-2.558-.447 6.092 6.092 0 0 1-2.084-1.275 5.934 5.934 0 0 1-1.388-1.994 6.892 6.892 0 0 1-.508-2.601c0-.893.172-1.777.508-2.601a6.027 6.027 0 0 1 1.388-1.994 6.191 6.191 0 0 1 2.084-1.275 7.284 7.284 0 0 1 2.558-.447 5.704 5.704 0 0 1 2.286.447c.678.28 1.285.716 1.772 1.275a5.887 5.887 0 0 1 1.104 1.994c.265.841.394 1.72.384 2.604v1.196h-8.428c.111.66.443 1.26.939 1.698.5.413 1.129.627 1.772.604a2.688 2.688 0 0 0 1.512-.41c.424-.277.795-.631 1.092-1.046zm-31.676-9.964h3.491v1.637h.047c.128-.254.291-.488.485-.694a3.51 3.51 0 0 1 .75-.605 4.176 4.176 0 0 1 2.203-.622 4.543 4.543 0 0 1 2.191.52c.649.362 1.157.94 1.441 1.637.341-.693.87-1.27 1.524-1.661a4.549 4.549 0 0 1 2.203-.496c.689-.02 1.374.12 2.002.411.515.25.957.633 1.282 1.112.326.505.557 1.069.679 1.661.141.671.21 1.356.207 2.043v7.1h-3.632v-7.01a2.83 2.83 0 0 0-.355-1.45 1.337 1.337 0 0 0-.54-.48 1.304 1.304 0 0 0-.706-.124 2.348 2.348 0 0 0-1.051.211 1.784 1.784 0 0 0-.68.605c-.176.26-.3.554-.366.864-.072.341-.107.69-.106 1.039v6.344h-3.632v-7.16a3.357 3.357 0 0 0-.172-.888 1.632 1.632 0 0 0-.472-.72 1.375 1.375 0 0 0-.957-.301 2.266 2.266 0 0 0-1.14.26 1.767 1.767 0 0 0-.662.694 3.023 3.023 0 0 0-.307.98c-.048.378-.072.76-.071 1.141v5.994h-3.632zm-20.536 0h3.491v1.637h.047c.127-.254.29-.488.484-.694.222-.236.475-.44.75-.605a4.2 4.2 0 0 1 .993-.447 4.076 4.076 0 0 1 1.21-.175 4.53 4.53 0 0 1 2.192.52c.648.362 1.156.94 1.441 1.637a3.97 3.97 0 0 1 1.524-1.661 4.572 4.572 0 0 1 2.209-.496 4.43 4.43 0 0 1 1.996.411c.515.25.957.633 1.282 1.112a4.81 4.81 0 0 1 .679 1.661c.14.671.21 1.356.207 2.043v7.1h-3.633v-7.01a2.829 2.829 0 0 0-.354-1.45 1.33 1.33 0 0 0-.54-.481 1.296 1.296 0 0 0-.706-.123 2.371 2.371 0 0 0-1.052.211 1.789 1.789 0 0 0-.679.605c-.176.26-.301.554-.366.864-.072.341-.108.69-.106 1.039v6.344h-3.633v-7.16a3.09 3.09 0 0 0-.171-.888 1.643 1.643 0 0 0-.473-.72 1.37 1.37 0 0 0-.956-.301 2.224 2.224 0 0 0-1.134.26 1.732 1.732 0 0 0-.668.694c-.158.305-.26.637-.301.98a7.93 7.93 0 0  ...
# <script defer="defer" src="https://d1nuzc1w51n1es.cloudfront.net/4ae2ce117ca6d89d7b27.js"></script>
# <style>
#     #flash-snackbar {
#         font-size: 14px;
#         visibility: hidden;
#         min-width: 250px;
#         margin-left: -125px;
#         background-color: #0078FF;
#         color: #fff;
#         text-align: center;
#         border-radius: 2px;
#         padding: 16px;
#         position: fixed;
#         z-index: 999;
#         left: 50%;
#         top: 30px;
#         border-radius: 8px;
#     }
#
#     #flash-snackbar.show {
#         visibility: visible;
#         -webkit-animation: fadein 0.5s, fadeout 0.5s 2.5s;
#         animation: fadein 0.5s, fadeout 0.5s 2.5s;
#     }
#
#     @-webkit-keyframes fadein {
#         from {top: 0; opacity: 0;}
#         to {top: 30px; opacity: 1;}
#     }
#
#     @keyframes fadein {
#         from {top: 0; opacity: 0;}
#         to {top: 30px; opacity: 1;}
#     }
#
#     @-webkit-keyframes fadeout {
#         from {top: 30px; opacity: 1;}
#         to {top: 0; opacity: 0;}
#     }
#
#     @keyframes fadeout {
#         from {top: 30px; opacity: 1;}
#         to {top: 0; opacity: 0;}
#     }
# </style>
# <script>
#   const showFlash = () => {
#     const messageContainer = document.querySelector('body[data-flash-message]');
#     if (!messageContainer || !messageContainer.dataset.flashMessage) return;
#
#     const snackbarContainer = document.querySelector("#flash-snackbar");
#     if (!snackbarContainer) return;
#
#     snackbarContainer.textContent = messageContainer.dataset.flashMessage;
#     snackbarContainer.classList.add("show");
#     setTimeout(() => {
#       snackbarContainer.classList.remove("show");
#     }, 3000);
#   }
#
#   document.addEventListener('DOMContentLoaded', showFlash);
# </script>
# <div id="flash-snackbar"></div>
# </body>
# </html>

# %%
spenTag = bsObj.findAll(name="span", attrs={"class":"NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS"}  )
# Out:
# <ipython-input-91-d72ec5e5cf0f>:1: DeprecationWarning: Call to deprecated method findAll. (Replaced by find_all) -- Deprecated since version 4.0.0.
#   spenTag = bsObj.findAll(name="span", attrs={"class":"NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS"}  )

# %%
spenTag
# Out:
# [<span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">교육 홈</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">강의</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">국비지원</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">데브코스</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">MY 스쿨</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">수강 중인 코스</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">관리 중인 코스</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">문제은행</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">수익 관리</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">지급 정보 관리</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">강사 신청</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">강사/멘토풀 등록</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">캠퍼스</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">채용 홈</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">채용 공고</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">채용 공고</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">받은 제안</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">지원한 포지션</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">북마크한 포지션</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">채용 프로그램</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">채용 프로그램</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">접수한 채용 프로그램</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">이력서</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">코딩테스트 문제</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">모든 문제</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">기초 문제</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">입문 문제</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">알고리즘 고득점 Kit</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">SQL 고득점 Kit</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">과제테스트</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">Q&amp;A</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">스킬체크</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">교육 홈</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">강의</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">국비지원</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">데브코스</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">MY 스쿨</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">수강 중인 코스</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">관리 중인 코스</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">문제은행</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">수익 관리</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">지급 정보 관리</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">강사 신청</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">강사/멘토풀 등록</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">캠퍼스</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">채용 홈</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">채용 공고</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">채용 공고</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">받은 제안</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">지원한 포지션</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">북마크한 포지션</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">채용 프로그램</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">채용 프로그램</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">접수한 채용 프로그램</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">이력서</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">코딩테스트 문제</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">모든 문제</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">기초 문제</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">입문 문제</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">알고리즘 고득점 Kit</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">SQL 고득점 Kit</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">과제테스트</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">Q&amp;A</span>,
#  <span class="NavLinkstyle__LinkText-sc-a5lqib-1 jsnXoS">스킬체크</span>]

# %%
textList = []
classList = []

# %%
for i in range (len(spenTag)):
    eachTag = spenTag[i]
    eachTagText = eachTag.text
    eachTagclass = eachTag.attrs["class"]
    textList.append(eachTagText)
    classList.append(eachTagclass)

# %%
df = pd.DataFrame(zip(textList, classList) , columns = ["text" , "class"])

# %%
df
# Out:
#              text                                         class
# 0            교육 홈  [NavLinkstyle__LinkText-sc-a5lqib-1, jsnXoS]
# 1              강의  [NavLinkstyle__LinkText-sc-a5lqib-1, jsnXoS]
# 2            국비지원  [NavLinkstyle__LinkText-sc-a5lqib-1, jsnXoS]
# 3            데브코스  [NavLinkstyle__LinkText-sc-a5lqib-1, jsnXoS]
# 4           MY 스쿨  [NavLinkstyle__LinkText-sc-a5lqib-1, jsnXoS]
# ..            ...                                           ...
# 123  알고리즘 고득점 Kit  [NavLinkstyle__LinkText-sc-a5lqib-1, jsnXoS]
# 124   SQL 고득점 Kit  [NavLinkstyle__LinkText-sc-a5lqib-1, jsnXoS]
# 125         과제테스트  [NavLinkstyle__LinkText-sc-a5lqib-1, jsnXoS]
# 126           Q&A  [NavLinkstyle__LinkText-sc-a5lqib-1, jsnXoS]
# 127          스킬체크  [NavLinkstyle__LinkText-sc-a5lqib-1, jsnXoS]
#
# [128 rows x 2 columns]
